# %%
from datasets import load_dataset

# %%
dataset=load_dataset('rajpurkar/squad', cache_dir='.')

# %%
dataset.save_to_disk('./dataset/squad-v1.1')
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/10570 [00:00<?, ? examples/s]

# %%
dataset=load_dataset('rajpurkar/squad_v2', cache_dir='.')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/16.4M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
dataset.save_to_disk('./squad-v2')
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
ls squad*
# Out:
# squad-v1.1:
# dataset_dict.json  train/             validation/
#
# squad-v2:
# dataset_dict.json  train/             validation/
